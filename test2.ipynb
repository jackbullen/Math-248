# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # $$f   = e^{-x^2}$$

# %% [markdown]
# **how to numerically integrate f?**

# %%
f = lambda x: np.exp(-x**2)

xs = np.linspace(5, 10, 100)

for i, xi in enumerate(xs):
    print(i, xi)

    # now what?
# Out:
# 0 5.0
# 1 5.05050505050505
# 2 5.101010101010101
# 3 5.151515151515151
# 4 5.202020202020202
# 5 5.252525252525253
# 6 5.303030303030303
# 7 5.353535353535354
# 8 5.404040404040404
# 9 5.454545454545454
# 10 5.505050505050505
# 11 5.555555555555555
# 12 5.606060606060606
# 13 5.656565656565657
# 14 5.707070707070707
# 15 5.757575757575758
# 16 5.808080808080808
# 17 5.858585858585858
# 18 5.909090909090909
# 19 5.959595959595959
# 20 6.01010101010101
# 21 6.0606060606060606
# 22 6.111111111111111
# 23 6.161616161616162
# 24 6.212121212121212
# 25 6.262626262626263
# 26 6.313131313131313
# 27 6.363636363636363
# 28 6.414141414141414
# 29 6.4646464646464645
# 30 6.515151515151516
# 31 6.565656565656566
# 32 6.616161616161616
# 33 6.666666666666667
# 34 6.717171717171717
# 35 6.767676767676768
# 36 6.818181818181818
# 37 6.8686868686868685
# 38 6.919191919191919
# 39 6.96969696969697
# 40 7.020202020202021
# 41 7.070707070707071
# 42 7.121212121212121
# 43 7.171717171717171
# ...
