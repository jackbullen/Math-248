# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def f(z):
    return z**3 +z**2 - 1

# %%
def df(z):
    return 3*z**2

# %%
x = np.linspace(-3.5, 3.5, 100)
y = np.linspace(-3.5, 3.5, 100)
X, Y = np.meshgrid(x, y)

# %%
for tony in tonys:
    plt.figure()
    plt.contour(X, Y, f(X**2+Y**2), [0,2,4,8,16], colors='k', linewidths=1)
    plt.plot(0, 0, 'bo', ms=10)

    # ellipse
    t = np.linspace(0, 2*np.pi, 100)
    plt.plot(2*np.cos(t), 3*np.sin(t), 'b', linewidth=1)

    t = np.linspace(-3, 3, 100)
    plt.plot(t, 3*t, 'k', linewidth=1)

    # binary star
    t = np.linspace(0, 2*np.pi, 100)
    plt.plot(2*np.cos(t), 2*np.sin(t), 'b', linewidth=1)
    plt.plot(1+np.cos(t), np.sin(t), 'b', linewidth=1)

    # saddle point
    t = np.linspace(-3, 3, 100)
    plt.plot(t, t**tony, 'r', linewidth=1)
# Out:
# /var/folders/b6/zjrzfvq14h12kvt3_h7c4fwr0000gn/T/ipykernel_35069/3699174238.py:21: RuntimeWarning: invalid value encountered in power
#   plt.plot(t, t**tony, 'r', linewidth=1)
# /var/folders/b6/zjrzfvq14h12kvt3_h7c4fwr0000gn/T/ipykernel_35069/3699174238.py:3: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   plt.figure()
